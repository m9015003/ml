31'],
#               dtype='datetime64[ns]', freq='B')

# %%
import numpy as np
np.random.randint(0,10,len(range))
ts = pd.Series(np.random.randint(0,10,len(range)), index=range)
ts
# Out:
# 2018-12-03    7
# 2018-12-04    3
# 2018-12-05    6
# 2018-12-06    0
# 2018-12-07    9
# 2018-12-10    7
# 2018-12-11    2
# 2018-12-12    2
# 2018-12-13    3
# 2018-12-14    4
# 2018-12-17    8
# 2018-12-18    5
# 2018-12-19    8
# 2018-12-20    6
# 2018-12-21    2
# 2018-12-24    7
# 2018-12-25    0
# 2018-12-26    6
# 2018-12-27    4
# 2018-12-28    8
# 2018-12-31    3
# Freq: B, dtype: int64

# %%
# to_dates
dates = ['2018/01/10']
dt = pd.to_datetime(dates)
type(dt[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# time period
period = pd.Period('2018-01', freq='D')
period
# Out:
# Period('2018-01-01', 'D')

# %%
period+1
# Out:
# Period('2018-01-02', 'D')

# %%
period
# Out:
# Period('2018-01-01', 'D')

# %%
periodM = pd.Period('2018-02', freq='M')
periodM
# Out:
# Period('2018-02', 'M')

# %%
periodM+1
# Out:
# Period('2018-03', 'M')

# %%
period.start_time
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
period.end_time
# Out:
# Timestamp('2018-01-01 23:59:59.999999999')

# %%
peroidM.start_time
# Out:
# Timestamp('2018-02-01 00:00:00')

# %%
periodM.end_time
# Out:
# Timestamp('2018-02-28 23:59:59.999999999')

# %%
periodQ = pd.Period('2018-1',freq="Q-Jan")
periodQ
# Out:
# Period('2018Q4', 'Q-JAN')

# %%
periodQ.start_time
# Out:
# Timestamp('2017-11-01 00:00:00')

# %%
periodQ.end_time
# Out:
# Timestamp('2018-01-31 23:59:59.999999999')

# %%
periodQ1 = pd.Period('2018-5',freq="Q-Jan")
periodQ1
# Out:
# Period('2019Q2', 'Q-JAN')

# %%
idx = pd.period_range('2017-01', '2017-08', freq='M')
idx
# Out:
# PeriodIndex(['2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
#              '2017-07', '2017-08'],
#             dtype='period[M]', freq='M')

# %%
idx[0].start_time,idx[0].end_time
# Out:
# (Timestamp('2017-01-01 00:00:00'), Timestamp('2017-01-31 23:59:59.999999999'))

# %%
idx = pd.period_range('2017-01', periods=10, freq='M')
idx
# Out:
# PeriodIndex(['2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
#              '2017-07', '2017-08', '2017-09', '2017-10'],
#             dtype='period[M]', freq='M')

# %%
ps = pd.Series(np.random.randn(len(idx)), idx)
ps
# Out:
# 2017-01    0.067021
# 2017-02   -0.131526
# 2017-03    0.708771
# 2017-04   -0.125144
# 2017-05    0.896406
# 2017-06   -0.307696
# 2017-07   -1.051575
# 2017-08    0.457905
# 2017-09    1.308465
# 2017-10   -0.171955
# Freq: M, dtype: float64

# %%
ps.index
# Out:
# PeriodIndex(['2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
#              '2017-07', '2017-08', '2017-09', '2017-10'],
#             dtype='period[M]', freq='M')

# %%
ps['2017-01':'2017-03']
# Out:
# 2017-01    0.067021
# 2017-02   -0.131526
# 2017-03    0.708771
# Freq: M, dtype: float64

# %%
pst = ps.to_timestamp()

# %%
pst
# Out:
# 2017-01-01    0.067021
# 2017-02-01   -0.131526
# 2017-03-01    0.708771
# 2017-04-01   -0.125144
# 2017-05-01    0.896406
# 2017-06-01   -0.307696
# 2017-07-01   -1.051575
# 2017-08-01    0.457905
# 2017-09-01    1.308465
# 2017-10-01   -0.171955
# Freq: MS, dtype: float64

# %%
wmt = pd.read_csv('wmt.csv')
wmt
# Out:
#   Line Item  2017Q1  2017Q2  2017Q3  2017Q4  2018Q1
# 0   Revenue  115904  120854  118179  130936  117542
# 1  Expenses   86544   89485   87484   97743   87688
# 2    Profit   29360   31369   30695   33193   29854

# %%
wmt = wmt.T
wmt.T
# Out:
#   Line Item  2017Q1  2017Q2  2017Q3  2017Q4  2018Q1
# 0   Revenue  115904  120854  118179  130936  117542
# 1  Expenses   86544   89485   87484   97743   87688
# 2    Profit   29360   31369   30695   33193   29854
